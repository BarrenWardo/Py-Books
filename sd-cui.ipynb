# %% [markdown]
# <a href="https://www.kaggle.com/code/barrenwardo/sd-cui?scriptVersionId=154513077" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !git clone "https://github.com/comfyanonymous/ComfyUI"

# %%
# %cd "/kaggle/working/ComfyUI"
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu121
# !pip install safetensors
# !pip install transformers
# !sudo apt-get install aria2 -y
# !pip install simpleeval
# !pip install lpips
# !npm install -g npm
# !pip install numpy==1.22.1
# !pip install cupy-cuda11x
# !pip install dill==0.3.1.1
# !pip install pyarrow==9.0.0
# !pip install pandas==1.5.3
# !pip install protobuf==4.25.1
# !pip install dask==2023.7.1
# !pip install distributed==2023.7.1
# !pip install packaging
# !pip install shapely
# !pip install scipy
# !pip install -r requirements.txt
# !pip install pyngrok

# %%
# %cd "/kaggle/working/ComfyUI/custom_nodes"
# !git clone "https://github.com/ltdrdata/ComfyUI-Manager"
# !git clone "https://github.com/jags111/efficiency-nodes-comfyui"
# !git clone "https://github.com/pythongosssss/ComfyUI-Custom-Scripts"
# !git clone "https://github.com/ssitu/ComfyUI_UltimateSDUpscale"
# !git clone "https://github.com/11cafe/comfyui-workspace-manager"

# %%
#JuggernautXL v7
# !aria2c "https://civitai.com/api/download/models/240840?type=Model&format=SafeTensor&size=full&fp=fp16" -d "/kaggle/working/ComfyUI/models/checkpoints" --summary-interval=5 --file-allocation=none --keep-unfinished-download-result=false -c --download-result=full
#4xUltraSharp
# !aria2c "https://civitai.com/api/download/models/125843?type=Model&format=PickleTensor" -d "/kaggle/working/ComfyUI/models/upscale_models" --summary-interval=5 --file-allocation=none --keep-unfinished-download-result=false -c --download-result=full
#SDXL VAE
# !aria2c "https://huggingface.co/stabilityai/sdxl-vae/resolve/main/sdxl_vae.safetensors?download=true" -d "/kaggle/working/ComfyUI/models/vae" -o "sdxl_vae.safetensors" --summary-interval=5 --file-allocation=none --keep-unfinished-download-result=false -c --download-result=full
#1.5 VAE
#!aria2c "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors?download=true" -d "/kaggle/working/ComfyUI/models/vae" -o "vae-ft-mse-840000-ema-pruned.safetensors" --summary-interval=5 --file-allocation=none --keep-unfinished-download-result=false -c --download-result=full

#TEMPLATES - Remove # and replace download-link in aria2c code line
#Checkpoints
#!aria2c "download-link" -d "/kaggle/working/ComfyUI/models/checkpoints" --summary-interval=5 --file-allocation=none --keep-unfinished-download-result=false -c --download-result=full
#ControlNet
#!aria2c "download-link" -d "/kaggle/working/ComfyUI/models/controlnet" --summary-interval=5 --file-allocation=none --keep-unfinished-download-result=false -c --download-result=full
#Embeddings / Textual Inversions
#!aria2c "download-link" -d "/kaggle/working/ComfyUI/models/embeddings" --summary-interval=5 --file-allocation=none --keep-unfinished-download-result=false -c --download-result=full
#LoRAs
#!aria2c "download-link" -d "/kaggle/working/ComfyUI/models/loras" --summary-interval=5 --file-allocation=none --keep-unfinished-download-result=false -c --download-result=full
#Upscalers
#!aria2c "download-link" -d "/kaggle/working/ComfyUI/models/upscale_models" --summary-interval=5 --file-allocation=none --keep-unfinished-download-result=false -c --download-result=full
#VAE
#!aria2c "download-link" -d "/kaggle/working/ComfyUI/models/vae" --summary-interval=5 --file-allocation=none --keep-unfinished-download-result=false -c --download-result=full

# %%
#NGROK

# %cd "/kaggle/working/ComfyUI"

from pyngrok import ngrok

ngrok.set_auth_token("your-ngrok-token")

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
    while True:
        time.sleep(0.5)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        result = sock.connect_ex(('127.0.0.1', port))
        if result == 0:
            break
        sock.close()
    print("\nComfyUI finished loading, trying to launch ngrok (if it gets stuck here ngrok is having issues)\n")

    public_url = ngrok.connect(port)
    print(f"Ngrok tunnel is live at: {public_url}")

threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server

# %% [markdown]
# #DO NOT USE - Depreciated
# #LocalTunnel
#
# %cd "/kaggle/working/ComfyUI"
#
# !npm install -g localtunnel
#
# import subprocess
# import threading
# import time
# import socket
# import urllib.request
#
# def iframe_thread(port):
#   while True:
#       time.sleep(0.5)
#       sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#       result = sock.connect_ex(('127.0.0.1', port))
#       if result == 0:
#         break
#       sock.close()
#   print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")
#
#   print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
#   p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
#   for line in p.stdout:
#     print(line.decode(), end='')
#
#
# threading.Thread(target=iframe_thread, daemon=True, args=(8108,)).start()
#
# !python main.py --dont-print-server

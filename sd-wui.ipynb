# %% [markdown]
# <a href="https://www.kaggle.com/code/barrenwardo/sd-wui?scriptVersionId=156135492" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !git clone "https://github.com/AUTOMATIC1111/stable-diffusion-webui"

# %%
#Extensions
# %cd "/kaggle/working/stable-diffusion-webui/extensions"
# !git clone "https://github.com/etherealxx/batchlinks-webui"
# !git clone "https://github.com/Coyote-A/ultimate-upscale-for-automatic1111"
# !git clone "https://github.com/Bing-su/adetailer"
# !git clone "https://github.com/thomasasfk/sd-webui-aspect-ratio-helper"
# !git clone "https://github.com/AlUlkesh/stable-diffusion-webui-images-browser"
# !git clone "https://github.com/Mikubill/sd-webui-controlnet"
# !git clone "https://github.com/ahgsql/StyleSelectorXL"
# !git clone "https://github.com/javsezlol1/Stylez"
# !git clone "https://github.com/BlafKing/sd-civitai-browser-plus"

#Optional (if needed remove # from the beginning of the line to install)
#!git clone "https://github.com/ModelSurge/sd-webui-comfyui"
#!git clone "https://github.com/hako-mikan/sd-webui-regional-prompter"
#!git clone "https://github.com/0xbitches/sd-webui-lcm"
#!git clone "https://github.com/Gourieff/sd-webui-reactor"

# %cd "./Stylez"
# !git clone "https://huggingface.co/FredZhang7/distilgpt2-stable-diffusion-v2"

# %cd "/kaggle/working/stable-diffusion-webui"
# !pip install -r requirements.txt

# %%
# %cd "/kaggle/working/stable-diffusion-webui"
# !python launch.py \
    --ngrok "2ZtQkOOqEFKupDdNQ8hOp3Na3cx_34ARUgUHoghippzSPdNdp" \
    --medvram-sdxl \
    --no-half-vae \
    --api \
    --skip-torch-cuda-test \
    --no-download-sd-model \
    --enable-insecure-extension-access \
    --update-all-extensions \
    --gradio-queue \
    --ckpt-dir "/kaggle/temp"

# %% [markdown]
# --------------------------------

# %%
#Upload your own custom settings. File should be named "config.json"
# !wget "remote_url_to_your_settings" -O "/kaggle/working/stable-diffusion-webui/config.json"

# %%
#Remove all files from a folder
import os
import glob

# Replace with the path of your folder. Currently set to Checkpoint folder.
folder_path = "/kaggle/working/stable-diffusion-webui/models/Stable-diffusion"  

files_to_delete = glob.glob(os.path.join(folder_path, '*'))

for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except Exception as e:
        print(f"Error deleting {file_path}: {e}")

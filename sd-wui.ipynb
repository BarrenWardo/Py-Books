# %%
# !git clone "https://github.com/AUTOMATIC1111/stable-diffusion-webui"
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 28998, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 28998 (delta 26), reused 26 (delta 15), pack-reused 28952
# Receiving objects: 100% (28998/28998), 32.88 MiB | 33.11 MiB/s, done.
# Resolving deltas: 100% (20300/20300), done.

# %%
# %cd "/kaggle/working/stable-diffusion-webui"
#!pip install xformers
# !pip install pyngrok
# !sudo apt-get install aria2 -y
# Out:
# /kaggle/working/stable-diffusion-webui
# ...
#   Obtaining dependency information for pyngrok from https://files.pythonhosted.org/packages/d6/6c/09c3548b51c006274f3e25b91463f07b3fe0615177dd9bbe5aa71e542c68/pyngrok-7.0.3-py3-none-any.whl.metadata
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libaria2-0 libc-ares2 libssh2-1
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2 libssh2-1
# 0 upgraded, 4 newly installed, 0 to remove and 71 not upgraded.
# Need to get 1622 kB of archives.
# After this operation, 5817 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.2 [45.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libssh2-1 amd64 1.10.0-3 [109 kB]
# ...

# %%
# !aria2c "https://civitai.com/api/download/models/128713?type=Model&format=SafeTensor&size=pruned&fp=fp16" -d "/kaggle/working/stable-diffusion-webui/models/Stable-diffusion" --summary-interval=5 --file-allocation=none --keep-unfinished-download-result=false -c --download-result=full
# Out:
# 12/12 16:20:51 [NOTICE] Downloading 1 item(s)
#
# 12/12 16:20:51 [NOTICE] CUID#7 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/53515/model/dreamshaper8Pruned.hz5Q.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22dreamshaper_8.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20231212/us-east-1/s3/aws4_request&X-Amz-Date=20231212T162051Z&X-Amz-SignedHeaders=host&X-Amz-Signature=67bd1c3a4ed8bab5f22a71ff53ee65a111b32ad0edce75567b5724964711b2ee
#  *** Download Progress Summary as of Tue Dec 12 16:20:57 2023 ***              9s]m
# ...
# [#3310e8 441MiB/1.9GiB(21%) CN:1 DL:82MiB ETA:19s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/dreamshaper_8.safetensors
# -------------------------------------------------------------------------------
#
# ...

# %%
# %cd "/kaggle/working/stable-diffusion-webui"

# !pip install -r requirements.txt

from pyngrok import ngrok

ngrok.set_auth_token("21a15rt3rj6VyF8GAuLJDu5K5hb_468b1uCsq2LyRLouvY2qV")

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
    while True:
        time.sleep(0.5)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        result = sock.connect_ex(('127.0.0.1', port))
        if result == 0:
            break
        sock.close()
    print("\nStable Diffusion WebUI finished loading, trying to launch ngrok (if it gets stuck here ngrok is having issues)\n")

    public_url = ngrok.connect(port)
    print(f"Ngrok tunnel is live at: {public_url}")

threading.Thread(target=iframe_thread, daemon=True, args=(7860,)).start()

# !python launch.py --skip-torch-cuda-test
# Out:
# /kaggle/working/stable-diffusion-webui
# ...
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Python 3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:40:32) [GCC 12.3.0]
# Version: v1.6.1
# Commit hash: 4afaaf8a020c1df457bcf7250cb1c7f609699fa7
# ...
# ReActor preheating... Device: CUDA
# Launching Web UI with arguments: --skip-torch-cuda-test
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# No module 'xformers'. Proceeding without it.
# ...
